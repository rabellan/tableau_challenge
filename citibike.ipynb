# %% [markdown]
# ## Citibike Data for Jersey City for October - December of 2023

# %%
# Import dependencies
import pandas as pd

# %%
# Create empty list to contain combined csv files
combined_csv_list = []

# List of Jersey City Citi Bike csv file names to be combined 
jc_csv_list = ['data/JC-202312-citibike-tripdata.csv', 'data/JC-202311-citibike-tripdata.csv', 'data/JC-202310-citibike-tripdata.csv']

# Loop through each file in the jc_csv_list
for file in jc_csv_list:
    # Read the file into a dataframe
    df_jc = pd.read_csv(file)

    # Append the dataframe to the combined_csv_list
    combined_csv_list.append(df_jc)

# Concatenate all dataframes in the list into one dataframe
df = pd.concat(combined_csv_list)

# Show dataframe
df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      DAE3C13A5FAAB089   classic_bike  2023-12-29 16:02:20
# 1      1EC6BE46ACF2DE11   classic_bike  2023-12-06 01:58:32
# 2      105CA439B9CBF57C   classic_bike  2023-12-06 20:15:11
# 3      DC1C46F6090FA1DB   classic_bike  2023-12-09 13:54:19
# 4      04EAEAAD6D32A664   classic_bike  2023-12-02 17:30:34
# ...                 ...            ...                  ...
# 97579  0227E77D4C1C6B31  electric_bike  2023-10-23 21:39:52
# 97580  5CF1E019B813A681  electric_bike  2023-10-26 16:14:05
# 97581  3AE1602D96E05800   classic_bike  2023-10-19 19:31:29
# 97582  DE69107CECA20727   classic_bike  2023-10-28 04:05:04
# 97583  2B19D514C0C48482   classic_bike  2023-10-08 18:18:48
#
#                   ended_at       start_station_name start_station_id  \
# 0      2023-12-29 16:10:17             Brunswick St            JC023
# 1      2023-12-06 02:04:48             Brunswick St            JC023
# ...

# %%
# Save the dataframe to a CSV file
df.to_csv('data/citibike_oct_dec_2023.csv', index=False)
